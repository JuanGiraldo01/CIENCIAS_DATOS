# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanGiraldo01/CIENCIAS_DATOS/blob/main/Interpretacion_graficas_analisis_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ## el histograma representa la frecuencia de cada rango de peso en kg y una curva de densidad que nos ayuda a visualizar la tendencia de los datos, la mayoria de los pesos estan concentrados entre los 60kg y los 120kg, con un pico aprox en los 80 kg

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## la grafica de dispercion muestra la relacion entre la edad y el peso, la mayoria de los puntos estan entre los 20 y 40 años , en un rango de 60 kg a 120kg

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## la grafica de dispercion toma en cuenta para el analizis la relacion entre la edad y las veces que comen vegetales, con una densidad mayor en el rango de 2.00 que lo podriamos llamar (" la mayoria de veces ")

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## la grafica de dispercion toma en cuenta la relacion de edad y estatura para los diferentes pesos registrados, tomandolos como una grafica de calor, donde pudimos ver que mucha gente no es obesa, si no que es demasiado alta, tambien personas con pesos hasta de 150kg midiendo 1.8 m teniendo entre 20 y 30 años

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## Esta gráfica muestra la relación entre la altura y el peso,  La forma general del gráfico tiene un patrón de campana, donde la mayoría de los datos se concentra en el centro y se vuelve más disperso hacia los extremos. Esto sugiere que, en general, a mayor altura tiende a haber mayor peso.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## gráfico de barras que muestra la relación entre la edad y el peso. Las barras representan el peso promedio para diferentes rangos de edad. La tendencia general es que el peso aumenta con la edad.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## Este gráfico de barras muestra la relación entre la frecuencia de realizar CALC (que tanto toma alcohol) y la edad de las personas. Además, se diferencia por género, presentando barras separadas para mujeres (rojo) y hombres (azul).los hombres tienden a reportar "Always" CALC en mayor medida que las mujeres.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ##Esta gráfica de torta muestra la distribución de consumo de alcohol entre hombres y mujeres ( en porcentajes % ). La mayor parte (66.1%) siempre consume alcohol, mientras que el 30.5% lo hace con frecuencia. Solo el 3.4% lo hace a veces y el 0% no consume.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ## Este gráfico muestra la relación entre la edad y el tipo de obesidad. A medida que aumenta la edad, se observa una mayor presencia de tipos de obesidad más severos.  en las edades más avanzadas hay más casos de obesidad de tipos II y III.
